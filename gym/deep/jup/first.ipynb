# %%
import tensorflow as tf

# %%
from tensorflow import keras

# %%
from skimage import io
from skimage import transform

# %%
img = io.imread("../input/train/cat.100.jpg")

# %%
print(img)
# Out:
# [[[224 225 220]
#   [223 224 219]
#   [223 224 219]
#   ...
#   [245 242 249]
#   [245 242 249]
#   [245 242 249]]
#
#  [[222 223 218]
#   [222 223 218]
#   [223 224 219]
#   ...
#   [247 244 251]
#   [247 244 251]
#   [247 244 251]]
#
#  [[220 221 216]
#   [221 222 217]
#   [221 222 217]
#   ...
#   [247 246 252]
#   [248 247 253]
#   [248 247 253]]
#
#  ...
#
#  [[211 215 224]
#   [213 217 226]
#   [210 215 221]
#   ...
#   [217 211 211]
#   [217 211 211]
#   [217 211 211]]
#
#  [[211 215 224]
#   [213 217 226]
#   [210 215 221]
#   ...
#   [217 211 211]
#   [217 211 211]
#   [217 211 211]]
#
#  [[211 215 224]
#   [213 217 226]
#   [210 215 221]
#   ...
#   [217 211 211]
#   [217 211 211]
#   [217 211 211]]]

# %%
img.shape
# Out:
# (499, 403, 3)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
img_trim = img[100:300, 100:300, :]

# %%
plt.imshow(img_trim)

# %%
img_inv = img[:,:,-1]

# %%
plt.imshow(img_inv)

# %%
img_inv.shape
# Out:
# (499, 403)

# %%
img.shape
# Out:
# (499, 403, 3)

# %%
img_inv2 = img[:, ::-1]

# %%
plt.imshow(img_inv2)

# %%
img_resize = transform.resize(img, output_shape=(100,100))

# %%
plt.imshow(img_resize)

# %%
img_rotate = transform.rotate(img, angle=90)

# %%
plt.imshow(img_rotate)

# %%
rot = transform.AffineTransform(translation=(40,40))
img_affline = transform.warp(img,rot)

# %%
plt.imshow(img_affline)
