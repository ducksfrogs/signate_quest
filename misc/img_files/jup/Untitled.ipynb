# %%
from skimage import io
from skimage import transform
import numpy as np

# %%
img = io.imread('../input/302782756_d35cb3e468.jpg')

# %%
print(img)
print(type(img))
# Out:
# [[[131 152 173]
#   [132 153 174]
#   [133 154 175]
#   ...
#   [126 157 178]
#   [126 156 180]
#   [126 154 178]]
#
#  [[130 152 173]
#   [131 153 174]
#   [133 155 176]
#   ...
#   [128 160 183]
#   [126 158 181]
#   [125 155 181]]
#
#  [[128 153 173]
#   [131 153 174]
#   [133 155 176]
#   ...
#   [124 159 181]
#   [124 158 183]
#   [123 157 182]]
#
#  ...
#
#  [[180 199 213]
#   [184 203 217]
#   [188 206 218]
#   ...
#   [223 223 215]
#   [222 222 214]
#   [221 221 213]]
#
#  [[179 197 211]
#   [182 200 212]
#   [185 203 215]
#   ...
#   [223 223 215]
#   [222 222 214]
#   [221 221 213]]
#
#  [[174 188 201]
#   [178 192 203]
#   [181 195 206]
#   ...
#   [223 220 213]
#   [222 219 212]
#   [222 219 210]]]
# <class 'numpy.ndarray'>

# %%
print(img.shape)
# Out:
# (375, 500, 3)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
plt.subplot(1,3,1)
plt.imshow(img)
plt.subplot(1,3,2)
plt.imshow(img)
plt.subplot(1,3,3)
plt.imshow(img)

# %%
img_trim = img[100:300, 200:400,:]

# %%
plt.imshow(img_trim)

# %%
tmp = np.array([1,2,3,4,5])
tmp[::-1]
# Out:
# array([5, 4, 3, 2, 1])

# %%
img_inv = img[:, ::-1]

# %%
plt.imshow(img_inv)

# %%
img_inv2 = img[::-1, :,:]

# %%
plt.imshow(img_inv2)

# %%
img_resize = transform.resize(img, output_shape=(100,100))

# %%
plt.imshow(img_resize)

# %%
img.shape
# Out:
# (375, 500, 3)

# %%
img_resize.shape
# Out:
# (100, 100, 3)

# %%
img_rotete = transform.rotate(img, angle=80)

# %%
plt.imshow(img_rotete)

# %%
rot = transform.AffineTransform(translation=(40,40))
img_affine = transform.warp(img, rot)

plt.imshow(img_affine)
