# %%
from PIL import  Image, ImageDraw

im = Image.open('../input/train_data/cast_def_0_0.jpeg')

# %%
print(im.format)
# Out:
# JPEG

# %%
print(im.size)
# Out:
# (300, 300)

# %%
import matplotlib.pyplot as plt

# %%
im1 = Image.open("../input/train_data/cast_def_0_103.jpeg")
im2 = Image.open("../input/train_data/cast_def_0_15.jpeg")
im3 = Image.open("../input/train_data/cast_def_0_2384.jpeg")
im4 = Image.open("../input/train_data/cast_def_0_122.jpeg")
plt.figure(figsize=(12,12))
plt.subplot(1,4,1)
plt.imshow(im1)

plt.subplot(1,4,2)
plt.imshow(im2)

plt.subplot(1,4,3)
plt.imshow(im3)

plt.subplot(1,4,4)
plt.imshow(im4)

# %%
im = Image.new('RGB', (300,300), 'gray')
d = ImageDraw.Draw(im)
d.rectangle(xy=[(100, 220),(180, 270)], outline='red', width=3)

plt.imshow(im)

# %%
im = Image.open('../input/train_data/cast_def_0_107.jpeg')
new_image = im.point(lambda x: x*1.5)
plt.imshow(new_image)

# %%
new_image = temp_im.resize((60,60)).resize((300, 300))
plt.imshow(new_image)
